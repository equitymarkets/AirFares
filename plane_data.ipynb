# %%
import pandas as pd

# %%
file = 'Resources/AverageFare_Annual_2003.csv'

# %%
plane_df = pd.read_csv(file)
plane_df = plane_df.loc[:, ~plane_df.columns.str.contains('^Unnamed')]

# %%
plane_df.head(15)
# Out:
#     2021 Passenger Rank Airport Code  \
# 0                     1          LAX
# 1                     2          ORD
# 2                     3          ATL
# 3                     4          DEN
# 4                     5          EWR
# 5                     6          SEA
# 6                     7          DFW
# 7                     8          PHX
# 8                     9          MCO
# 9                    10          BOS
# 10                   11          JFK
# 11                   12          SFO
# 12                   13          LAS
# 13                   14          MSP
# 14                   15          PHL
#
#                                 Airport Name       City Name State Name  \
# 0                  Los Angeles International     Los Angeles         CA
# 1               Chicago O'Hare International  Chicago-O'Hare         IL
# 2   Hartsfield-Jackson Atlanta International         Atlanta         GA
# ...

# %%
file = 'Resources/AverageFare_Annual_2010.csv'

# %%
plane_df = pd.read_csv(file)

# %%
plane_df
